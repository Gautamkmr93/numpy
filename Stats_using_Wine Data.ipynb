# %%
#import numpy as np
import pandas as pd
import statistics as st

# %%
dataset=pd.read_csv('winequality-red.csv',sep=";",nrows=1000)
dataset.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0            7.4              0.70         0.00             1.9      0.076
# 1            7.8              0.88         0.00             2.6      0.098
# 2            7.8              0.76         0.04             2.3      0.092
# 3           11.2              0.28         0.56             1.9      0.075
# 4            7.4              0.70         0.00             1.9      0.076
#
#    free sulfur dioxide  total sulfur dioxide  density    pH  sulphates  \
# 0                 11.0                    34   0.9978  3.51       0.56
# 1                 25.0                    67   0.9968  3.20       0.68
# 2                 15.0                    54   0.9970  3.26       0.65
# 3                 17.0                    60   0.9980  3.16       0.58
# 4                 11.0                    34   0.9978  3.51       0.56
#
#    alcohol  quality
# 0      9.4        5
# 1      9.8        5
# 2      9.8        5
# ...

# %%
dataset.query('pH>=3.26')
# Out:
#      fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0              7.4              0.70         0.00            1.90      0.076
# 2              7.8              0.76         0.04            2.30      0.092
# 4              7.4              0.70         0.00            1.90      0.076
# 5              7.4              0.66         0.00            1.80      0.075
# 6              7.9              0.60         0.06            1.60      0.069
# ..             ...               ...          ...             ...        ...
# 993            7.1              0.34         0.28            2.00      0.082
# 995            7.7              0.60         0.06            2.00      0.079
# 996            5.6              0.66         0.00            2.20      0.087
# 997            5.6              0.66         0.00            2.20      0.087
# 999            6.4              0.69         0.00            1.65      0.055
#
# ...

# %%
mean_var=dataset['pH'].mean()

# %%
mean_var
# Out:
# 3.2990999999999997

# %%
#dataset.chlorides.median()
dataset['chlorides'].median()
# Out:
# 0.081

# %%
dataset.density.mode()
# Out:
# 0    0.9972
# dtype: float64

# %%
dataset.density.value_counts()
# Out:
# 0.99720    35
# 0.99760    34
# 0.99680    33
# 0.99800    29
# 0.99640    25
#            ..
# 0.99761     1
# 0.99517     1
# 0.99530     1
# 0.99733     1
# 0.99901     1
# Name: density, Length: 240, dtype: int64

# %%
range=dataset['fixed acidity'].max()-dataset['fixed acidity'].min()
range
# Out:
# 11.3

# %%
dataset['variance']=dataset['fixed acidity']-dataset['fixed acidity'].mean()
dataset
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0               7.4             0.700         0.00             1.9      0.076
# 1               7.8             0.880         0.00             2.6      0.098
# 2               7.8             0.760         0.04             2.3      0.092
# 3              11.2             0.280         0.56             1.9      0.075
# 4               7.4             0.700         0.00             1.9      0.076
# ...             ...               ...          ...             ...        ...
# 1594            6.2             0.600         0.08             2.0      0.090
# 1595            5.9             0.550         0.10             2.2      0.062
# 1596            6.3             0.510         0.13             2.3      0.076
# 1597            5.9             0.645         0.12             2.0      0.075
# 1598            6.0             0.310         0.47             3.6      0.067
#
# ...

# %%
dataset['volatile acidity'].var()
# Out:
# 0.03206237765155147

# %%
dataset['volatile acidity'].std()
# Out:
# 0.17905970415353498

# %%
dataset.quantile([.25, .75])
# Out:
#       fixed acidity  volatile acidity  citric acid  residual sugar  chlorides  \
# 0.25            7.1              0.39         0.09             1.9       0.07
# 0.75            9.2              0.64         0.42             2.6       0.09
#
#       free sulfur dioxide  total sulfur dioxide   density    pH  sulphates  \
# 0.25                  7.0                  22.0  0.995600  3.21       0.55
# 0.75                 21.0                  62.0  0.997835  3.40       0.73
#
#       alcohol  quality  variance
# 0.25      9.5      5.0 -1.219637
# 0.75     11.1      6.0  0.880363

# %%
dataset.skew()
# Out:
# fixed acidity           0.982751
# volatile acidity        0.671593
# citric acid             0.318337
# residual sugar          4.540655
# chlorides               5.680347
# free sulfur dioxide     1.250567
# total sulfur dioxide    1.515531
# density                 0.071288
# pH                      0.193683
# sulphates               2.428672
# alcohol                 0.860829
# quality                 0.217802
# variance                0.982751
# dtype: float64

# %%
#home work Outilers

# %%
dataset.columns
# Out:
# Index(['fixed acidity', 'volatile acidity', 'citric acid', 'residual sugar',
#        'chlorides', 'free sulfur dioxide', 'total sulfur dioxide', 'density',
#        'pH', 'sulphates', 'alcohol', 'quality'],
#       dtype='object')
